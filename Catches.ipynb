# %%
import cv2
import os
import numpy as np

# %%
def extract_frames_from_videos(video_dir, output_dir, frame_rate=5):
    class_names = ['Catches','Drops']  # Define class labels

    for class_name in class_names:
        class_folder = os.path.join(video_dir, class_name)
        output_class_dir = os.path.join(output_dir, 'extracted_frames', class_name)
        os.makedirs(output_class_dir, exist_ok=True)  # Create the output directory if it doesn't exist

        for video_file in os.listdir(class_folder):
            if video_file.endswith('.mp4'):
                video_path = os.path.join(class_folder, video_file)
                video = cv2.VideoCapture(video_path)
                success, image = video.read()
                frame_count = 0
                while success:
                    if frame_count % frame_rate == 0:  # Capture frame at specific intervals
                        frame_filename = f"{os.path.splitext(video_file)[0]}_frame_{frame_count}.jpg"
                        frame_output_path = os.path.join(output_class_dir, frame_filename)
                        image_resized = cv2.resize(image, (224, 224))  # Resize for CNN
                        cv2.imwrite(frame_output_path, image_resized)  # Save frame
                    success, image = video.read()
                    frame_count += 1

# %%
video_dir = 'Catches/'  # Path to your dataset directory 
output_dir = 'Catches/data/'  # Root directory where all data will be saved

# %%
extract_frames_from_videos(video_dir, output_dir)

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import numpy as np
import os
import cv2

# %%
import os
import cv2
import numpy as np
from keras.utils import to_categorical

def load_data_from_frames(output_dir, target_size=(224, 224)):
    """Load frames from directories and prepare the data for training."""
    class_names = ['Catches', 'Drops']
    data = []
    labels = []

    for class_id, class_name in enumerate(class_names):
        class_folder = os.path.join(output_dir, 'extracted_frames', class_name)
        for frame_file in os.listdir(class_folder):
            if frame_file.endswith('.jpg'):
                frame_path = os.path.join(class_folder, frame_file)
                print(f"Attempting to load image: {frame_path}")  # Debugging: print the path
                
                image = cv2.imread(frame_path)

                # Check if the image was loaded successfully
                if image is None:
                    print(f"Warning: Unable to load image {frame_path}. Skipping this file.")
                    continue  # Skip the current file if loading failed

                # Resize image to target size
                image = cv2.resize(image, target_size)
                
                # Ensure the image has 3 channels (RGB), convert to RGB if needed
                if image.shape[-1] != 3:
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                data.append(image)
                labels.append(class_id)  # Assign class label

    data = np.array(data)
    labels = np.array(labels)

    # Normalize the frames
    data = data.astype('float32') / 255.0

    # One-hot encode the labels
    labels = to_categorical(labels, num_classes=len(class_names))

    return data, labels

# %%
# Load frames and labels
frames_data, labels_data = load_data_from_frames(output_dir)
# Out:
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_0.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_10.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_100.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1000.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1005.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1010.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1015.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1020.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1025.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1030.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1035.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1040.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1045.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_105.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1050.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1055.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1060.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1065.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1070.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1075.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1080.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1085.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1090.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1095.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_110.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1100.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1105.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1110.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1115.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1120.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1125.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1130.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1135.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1140.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1145.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_115.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1150.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1155.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1160.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1165.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1170.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1175.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1180.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1185.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1190.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1195.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_120.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1200.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1205.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1210.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1215.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1220.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1225.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1230.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1235.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_1240.jpg
# Attempting to load image: Catches/data/extracted_frames\Catches\#IndvsAus #ViratKohli _frame_
jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1135.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1140.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1140.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1145.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1145.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_115.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_115.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1150.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1150.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1155.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1155.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1160.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1160.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1165.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1165.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1170.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1170.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1175.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1175.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1180.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1180.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1185.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1185.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1190.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1190.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1195.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1195.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_120.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_120.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1200.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1200.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1205.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1205.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1210.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1210.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1215.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1215.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Catches\10 Easy & Worst Dropped Catches In Cricket Ever ðŸ˜ž_frame_1220.jpg
# ...
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_735.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_740.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_740.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_745.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_745.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_75.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_75.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_750.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_750.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_755.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_755.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_760.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_760.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_765.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_765.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_770.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_770.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_775.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_775.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_780.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_780.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_785.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_785.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_790.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_790.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_795.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_795.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_80.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_80.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_800.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_800.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_805.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_805.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_810.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_810.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_815.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_815.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_820.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_820.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_825.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_825.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_830.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_830.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_835.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_835.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_840.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_840.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_845.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_845.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_85.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_85.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_850.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_850.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_855.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_855.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_860.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_860.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_865.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_865.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_870.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_870.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_875.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_875.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_880.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_880.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_885.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_885.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_890.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_890.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_895.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_895.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_90.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_90.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_900.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_900.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_905.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_905.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_910.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_910.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_915.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_915.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_920.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_920.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_925.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_925.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_930.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_930.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_935.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_935.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_940.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_940.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_945.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_945.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_95.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_95.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_950.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_950.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_955.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_955.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_960.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_960.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_965.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_965.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_970.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_970.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_975.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_975.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_980.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_980.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_985.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_985.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_990.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_990.jpg. Skipping this file.
# Attempting to load image: Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_995.jpg
# Warning: Unable to load image Catches/data/extracted_frames\Drops\ðŸ‘€ Is This The BEST Catch of All Time_! #shorts_frame_995.jpg. Skipping this file.

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(frames_data, labels_data, test_size=0.2, random_state=42)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, LSTM, Dense, TimeDistributed, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define the model
def create_cnn_lstm_model(input_shape):
    model = Sequential()
    
    # CNN part wrapped in TimeDistributed (to apply the CNN to each frame)
    model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu'), input_shape=input_shape))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
    
    model.add(TimeDistributed(Conv2D(128, (3, 3), activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
    
    model.add(TimeDistributed(Flatten()))
    
    # LSTM part
    model.add(LSTM(64, return_sequences=False))
    model.add(Dropout(0.5))
    
    # Fully connected layers
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    
    # Output layer (4 classes: No Ball, Legal Ball, Wide, LBW)
    model.add(Dense(4, activation='softmax'))
    
    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# Define the input shape: (10 frames, 224x224 pixels, 3 color channels)
input_shape = (10, 112, 112, 3)
model = create_cnn_lstm_model(input_shape)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#print the model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed (TimeDistributed)   │ (None, 10, 110, 110, 32)    │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_1 (TimeDistributed) │ (None, 10, 110, 110, 32)    │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 10, 55, 55, 32)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_3 (TimeDistributed) │ (None, 10, 53, 53, 64)      │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_4 (TimeDistributed) │ (None, 10, 53, 53, 64)      │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 10, 26, 26, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_6 (TimeDistributed) │ (None, 10, 24, 24, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_7 (TimeDistributed) │ (None, 10, 24, 24, 128)     │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_8 (TimeDistributed) │ (None, 10, 12, 12, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_9 (TimeDistributed) │ (None, 10, 18432)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 64)                  │       4,735,232 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,838,212 (18.46 MB)
#  Trainable params: 4,837,764 (18.45 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Data augmentation (to reduce overfitting and introduce more data variety)
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

# %%
# Apply augmentation frame by frame before creating sequences
def augment_frames(X_train):
    augmented_frames = []
    for frame in X_train:
        augmented_frame = datagen.random_transform(frame)
        augmented_frames.append(augmented_frame)
    return np.array(augmented_frames)

# %%
# Function to create frame sequences for the model
def create_frame_sequences(data, labels, sequence_length=10):
    sequences = []
    sequence_labels = []
    
    for i in range(0, len(data) - sequence_length, sequence_length):
        sequences.append(data[i:i + sequence_length])
        sequence_labels.append(labels[i + sequence_length - 1])  # Use the label of the last frame in the sequence
    
    return np.array(sequences), np.array(sequence_labels)

# %%
# Example data (X_train, y_train) should be processed with your dataset
# Assuming X_train and y_train are preprocessed
# Manually augment data frame by frame
X_train_augmented = augment_frames(X_train)

# %%
# Group the frames into sequences of 10 frames each
X_train_seq, y_train_seq = create_frame_sequences(X_train_augmented, y_train, sequence_length=10)
X_test_seq, y_test_seq = create_frame_sequences(X_test, y_test, sequence_length=10)

# %%
# Reshape to (batch_size, timesteps, 224*224*3) for LSTM input
X_train_seq = X_train_seq.reshape(X_train_seq.shape[0], X_train_seq.shape[1], -1)  # -1 flattens the last dimensions

# %%
# Define learning rate scheduler and checkpoint
checkpoint = ModelCheckpoint('catches_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)

# %%
# Train the model using the sequences of frames
history = model.fit(X_train_seq, y_train_seq,
                    epochs=50,
                    batch_size=4,
                    validation_data=(X_test_seq, y_test_seq),
                    callbacks=[checkpoint, reduce_lr])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Train the model using the sequences of frames
# ----> 2 history = model.fit(X_train_seq, y_train_seq,
#       3                     epochs=50,
#       4                     batch_size=4,
#       5                     validation_data=(X_test_seq, y_test_seq),
#       6                     callbacks=[checkpoint, reduce_lr])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tensorflow\python\framework\constant_op.py:96, in convert_to_eager_tensor(value, ctx, dtype)
#      76 """Converts the given `value` to an `EagerTensor`.
#      77
#      78 Note that this function could return cached copies of created constants for
#    (...)
#      90   TypeError: if `dtype` is not compatible with the type of t.
#      91 """
#      92 if isinstance(value, np.ndarray):
#      93   # Make a copy explicitly because the EagerTensor might share the underlying
#      94   # memory with the input array. Without this copy, users will be able to
#      95   # modify the EagerTensor after its creation by changing the input array.
# ---> 96   value = value.copy()
#      97 if isinstance(value, ops.EagerTensor):
#      98   if dtype is not None and value.dtype != dtype:
#
# MemoryError: Unable to allocate 5.76 GiB for an array with shape (1027, 10, 150528) and data type float32
